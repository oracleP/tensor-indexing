# %%
import torch

# %%
random_tensor=torch.rand(5)
print(random_tensor)
print(random_tensor.ndim)
# Out:
# tensor([0.4412, 0.9466, 0.4965, 0.2021, 0.9068])
# 1

# %%
random_tensor=torch.rand(2,5,5)
print(random_tensor)
print(random_tensor.ndim)
print(random_tensor.shape)
# Out:
# tensor([[[0.5975, 0.0321, 0.6080, 0.6326, 0.7480],
#          [0.4374, 0.6717, 0.1382, 0.0902, 0.5507],
#          [0.7876, 0.1966, 0.6372, 0.3121, 0.7010],
#          [0.2307, 0.6744, 0.3095, 0.1939, 0.3397],
#          [0.3185, 0.8374, 0.7839, 0.6296, 0.6036]],
#
#         [[0.8223, 0.9755, 0.3261, 0.6719, 0.4908],
#          [0.4778, 0.4780, 0.2997, 0.7392, 0.7183],
#          [0.3300, 0.5453, 0.4788, 0.6353, 0.6791],
#          [0.9435, 0.6878, 0.2818, 0.3217, 0.4844],
#          [0.2508, 0.6654, 0.2025, 0.7325, 0.6122]]])
# 3
# torch.Size([2, 5, 5])

# %%
torch.manual_seed(42)
random_tensor=torch.rand(5)
print(random_tensor)
# Out:
# tensor([0.8823, 0.9150, 0.3829, 0.9593, 0.3904])

# %% [markdown]
#  ## generated random integer

# %%
# torch.radint(low,high,size)
random_integer=torch.randint(-10,10,(5,5))
print(random_integer)
# Out:
# tensor([[-6,  9,  6,  2,  0],
#         [-4, -8,  7,  9, -3],
#         [-7, -7,  4,  3,  7],
#         [ 0, -1,  0,  9, -4],
#         [ 9,  5, -6,  8, -2]])

# %% [markdown]
# Creating noise image using pytorch

# %%
import matplotlib.pyplot as plt
#h,w of img 256*256
uniform_noise=torch.rand((256,256))
plt.imshow(uniform_noise,cmap='grey')
plt.title("uniform noise image")
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
uniform_noise_rgb=torch.rand(256,256,3)
plt.imshow(uniform_noise_rgb.numpy())
plt.title("image with rgb image ")
plt.axis('off')
plt.show()

# %%
print("Shape",uniform_noise_rgb.shape)
print("Data type",uniform_noise_rgb.dtype)
print("Min value",torch.min(uniform_noise_rgb))
print("Max value",torch.max(uniform_noise_rgb))
# Out:
# Shape torch.Size([256, 256, 3])
# Data type torch.float32
# Min value tensor(2.7418e-06)
# Max value tensor(1.0000)
